# %%
# !pip3 install -r pythonRobotics/PythonRobotics/requirements/requirements.txt
# Out:
# ...
#   Using cached numpy-2.3.5-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached scipy-1.17.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached cvxpy-1.7.5-cp313-cp313-macosx_10_13_universal2.whl.metadata (9.5 kB)
# ...
#   Using cached ecos-2.0.14-cp313-cp313-macosx_15_0_arm64.whl
# ...
#   Using cached pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached pytest_xdist-3.8.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached mypy-1.19.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.2 kB)
# ...
#   Using cached ruff-0.14.13-py3-none-macosx_11_0_arm64.whl.metadata (26 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (114 kB)
# ...

# %%
import sys
import pathlib

# sys.path.append(str(pathlib.Path(__file__).parent.parent.parent))

import math
import matplotlib.pyplot as plt
import numpy as np
